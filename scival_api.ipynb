# %%
import os
import requests
import json
import csv
import pandas as pd
#conda install -c conda-forge python-dotenv
from dotenv import load_dotenv
from time import sleep
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("API_KEY")
API_COUNT = 25
header = {
    "X-ELS-APIKey": API_KEY,
}
api_url = "http://api.elsevier.com/content/search/author?"

# %%
###### !!! CHANGE THESE ######
# columns of the input file

PATH_TO_INPUT_CSV = "sample.csv"
OUTPUT_FILEPATH = "output.csv"

cols = ['Last Name','First Name','Member Type','Mental Health & Addictions','Brain Development & Neurodevelopmental Disorders','Learning Memory & Dementias','Sensory Motor Systems & Movement Disorders','Brain Injury & Repair','Google Scholar?','GS Link']

# subjects that can be matched with the list of authors
subjects_list = ["NEUR", "BIOC", "MEDI", "PSYC"]

# affiliated institutions, cities, or countries
affiliation_list = ["The University of British Columbia", "Djavad Mowafaghian Centre for Brain Health", "BC Children's Hospital Research Institute", "University of British Columbia Okanagan", "University of British Columbia, Faculty of Medicine", "Vancouver"]

# %%
def get_api_json(query: str, start=0):
    params = {
        "query":query,
        "start":start,
        "count":API_COUNT,
    }
    try:
        response = requests.get(url=api_url, params=params, headers=header)
        response.raise_for_status
        data = json.loads(response.text)
    except requests.exceptions.HTTPError as e:
        print("HTTPS error: ", e)
    except requests.exceptions.RetryError as e:
        print("Max retries exceeded: ", e)
    return data

# %%
member_arr = []
with open(PATH_TO_INPUT_CSV, "r") as f:
    r = csv.reader(f)
    for row in r:
        if row[0] != "":
            member_arr.append(row)

# skip header rows
member_arr = member_arr[2:]
print(len(member_arr))
# Out:
# 129

# %%
with open(PATH_TO_INPUT_CSV, "r") as csvfile:
    r = csv.reader(csvfile)

# %%
last_names = []
first_names = []
affils = []
auth_ids = []
orcids = []
tags = []

warnings = []
subjects = []

no_search_results = []

for member in member_arr:
    start = 0
    sleep(1)

    lastname = member[0].strip()
    firstname = member[1].strip()

    print("searching for " + firstname + " " + lastname)

    query = f"authlastname({lastname}) and authfirst({firstname})"
    data = get_api_json(query, start=0)

    warning = ""

    num_authors_found = int(data["search-results"]['opensearch:totalResults'])
    
    author_idx = 0
    if num_authors_found == 0:
        print("no scival profile found for " + firstname + " " + lastname + "\n")
        no_search_results.append(member)
        continue

    # pages_to_search = int(num_authors_found//API_COUNT)
    
    found_match = True
    if num_authors_found > 1:
        print("multiple profiles found for " + firstname + " " + lastname)
        warning = warning + "multiple profiles; "
        first_match = False
        best_match = 0
        for author_number in range(num_authors_found):
            if author_number >= API_COUNT:
                break

            print("looking at profile " + str(author_number))
            try:
                if any([x in str(data["search-results"]["entry"][author_number]["affiliation-current"]) for x in affiliation_list]) and any([x in str(data["search-results"]["entry"][author_number]["subject-area"]) for x in subjects_list]):
                    print("subject and location match found")
                    print("updating best match")
                    best_match = author_number
                    break
            except:
                print("no affiliation with associated profile")

            try:
                if first_match == False and any([x in str(data["search-results"]["entry"][author_number]["subject-area"]) for x in subjects_list]):
                    print("subject match found")
                    if first_match == False:
                        print("updating best match")
                        best_match = author_number
                    first_match = True
            except:
                print("no subject with associated profile")

        if found_match == False:
            warning = warning + "no match! "
            print("no matching profile found")
        author_idx = best_match
    
    affil_name = ""
    try:
        affil_name = data["search-results"]["entry"][author_idx]["affiliation-current"]["affiliation-name"]
        if affil_name not in affiliation_list:
            warning = warning + "affiliation not in list"
    except:
        warning = "no affiliation"
        
    author_id = data["search-results"]["entry"][author_idx]["dc:identifier"].split(":")[1]
    # affil_id = data["search-results"]["entry"][0]["affiliation-current"]["affiliation-id"]

    subject = ""
    try:
        for i in data["search-results"]["entry"][author_idx]["subject-area"]:
            subject = f'{i["@abbrev"]} - {i["@frequency"]} publications; ' + subject
    except:
        pass

    orcid = ""
    try:
        orcid = data["search-results"]["entry"][author_idx]["orcid"]
    except:
        pass
    
    #find primary IRP to add as tag
    for i in range(3,8):
        if member[i].strip() == "Primary":
            tags.append(cols[i])

    scopus_lastname = data["search-results"]["entry"][i]["preferred-name"]['surname']
    scopus_firstname = data["search-results"]["entry"][i]["preferred-name"]['given-name']

    last_names.append(scopus_lastname)
    first_names.append(scopus_firstname)
    affils.append(affil_name)
    auth_ids.append(author_id)
    warnings.append(warning)
    subjects.append(subject)
    orcids.append(orcid)

    print("\n")
# Out:
# searching for Khaled Abd-Elrahman
#
#
# searching for Douglas Allan
# multiple profiles found for Douglas Allan
# looking at profile 0
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Doug Altshuler
# no scival profile found for Doug Altshuler
#
# searching for Vanessa Auld
#
#
# searching for Jehannine Austin
#
#
# searching for Shelina Babul
# multiple profiles found for Shelina Babul
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Shernaz Bamji
#
#
# searching for Phil Barker
# multiple profiles found for Phil Barker
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Steven Barnes
# multiple profiles found for Steven Barnes
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Alasdair Barr
#
#
# searching for Jason Barton
# multiple profiles found for Jason Barton
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# subject and location match found
# updating best match
#
#
# searching for Clare Beasley
#
#
# searching for Lara Boyd
# multiple profiles found for Lara Boyd
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Neil Cashman
# multiple profiles found for Neil Cashman
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Mark Cembrowski
#
#
# searching for Trisha Chakrabarty
#
#
# searching for Annie Ciernia
# multiple profiles found for Annie Ciernia
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Luke Clark
# multiple profiles found for Luke Clark
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Ann-Marie Craig
# multiple profiles found for Ann-Marie Craig
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Silke Cresswell
#
#
# searching for Peter Cripton
#
#
# searching for Max Cynader
#
#
# searching for Ryan D'Arcy
# multiple profiles found for Ryan D'Arcy
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
#
#
# searching for Adele Diamond
#
#
# searching for Doris Doudet
#
#
# searching for Lauren Emberson
#
#
# searching for Thalia Field
# multiple profiles found for Thalia Field
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Stan Floresco
#
#
# searching for Dean Foti
#
#
# searching for Sophia Frangou
#
#
# searching for Liisa Galea
#
#
# searching for Debbie Giaschi
#
#
# searching for Julien Gibon
# multiple profiles found for Julien Gibon
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
#
#
# searching for Daniel Goldowitz
# multiple profiles found for Daniel Goldowitz
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Michael Gordon
# multiple profiles found for Michael Gordon
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# looking at profile 3
# looking at profile 4
# looking at profile 5
# looking at profile 6
# looking at profile 7
# looking at profile 8
# looking at profile 9
# looking at profile 10
# looking at profile 11
# looking at profile 12
# looking at profile 13
# looking at profile 14
# looking at profile 15
# looking at profile 16
# subject and location match found
# updating best match
#
#
# searching for Ruth Grunau
#
#
# searching for Kurt Haas
# multiple profiles found for Kurt Haas
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Ilker Hacihaliloglu
#
#
# searching for Amani Hariri
# multiple profiles found for Amani Hariri
# looking at profile 0
# looking at profile 1
# looking at profile 2
#
#
# searching for Sherri Hayden
#
#
# searching for Anthony Herdman
#
#
# searching for Brett Hilton
# multiple profiles found for Brett Hilton
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
#
#
# searching for Robin Hsiung
# multiple profiles found for Robin Hsiung
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Tao Huan
# multiple profiles found for Tao Huan
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Judy Illes
#
#
# searching for Hee Yeon Im
# multiple profiles found for Hee Yeon Im
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Wilfred Jefferies
#
#
# searching for Kamyar Keramatian
#
#
# searching for Shannon Kolind
#
#
# searching for Piotr Kozlowski
# multiple profiles found for Piotr Kozlowski
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for John Kramer
# multiple profiles found for John Kramer
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# subject and location match found
# updating best match
#
#
# searching for Sarah Kraeutner
#
#
# searching for Charles Krieger
# multiple profiles found for Charles Krieger
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# looking at profile 3
# looking at profile 4
#
#
# searching for Ujendra Kumar
# multiple profiles found for Ujendra Kumar
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Raymond Lam
# multiple profiles found for Raymond Lam
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Donna Lang
#
#
# searching for Cornelia Laule
#
#
# searching for Blair Leavitt
# multiple profiles found for Blair Leavitt
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Duncan Leitch
# multiple profiles found for Duncan Leitch
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for David Li
# multiple profiles found for David Li
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Teresa Liu-Ambrose
#
#
# searching for Ian Mackenzie
# multiple profiles found for Ian Mackenzie
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Brian MacVicar
#
#
# searching for Manu Madhav
# multiple profiles found for Manu Madhav
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Joanne Matsubara
# multiple profiles found for Joanne Matsubara
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Benjamin Matthews
# multiple profiles found for Benjamin Matthews
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# looking at profile 3
# looking at profile 4
# subject and location match found
# updating best match
#
#
# searching for Martin McKeown
#
#
# searching for Erin Michalak
# multiple profiles found for Erin Michalak
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Freda Miller
# multiple profiles found for Freda Miller
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
#
#
# searching for Steven Miller
# multiple profiles found for Steven Miller
# looking at profile 0
# looking at profile 1
# subject match found
# updating best match
# looking at profile 2
# subject and location match found
# updating best match
#
#
# searching for Kota Mizumoto
#
#
# searching for Robert Molday
# multiple profiles found for Robert Molday
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Hakima Moukhles
#
#
# searching for Orson Moritz
#
#
# searching for Tim Murphy
# multiple profiles found for Tim Murphy
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Haakon Nygaard
#
#
# searching for Timothy O'Connor
# multiple profiles found for Timothy O'Connor
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# looking at profile 3
# looking at profile 4
# looking at profile 5
# looking at profile 6
# looking at profile 7
# subject and location match found
# updating best match
#
#
# searching for Joel Oger
# multiple profiles found for Joel Oger
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Ipek Oruc
# multiple profiles found for Ipek Oruc
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Daniela Palombo
#
#
# searching for William Panenka
# multiple profiles found for William Panenka
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Paul Pavlidis
# multiple profiles found for Paul Pavlidis
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Steven Pelech
# multiple profiles found for Steven Pelech
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Anthony Phillips
# multiple profiles found for Anthony Phillips
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Mahmoud Pouladi
#
#
# searching for Jacqueline Quandt
#
#
# searching for Manon Ranger
#
#
# searching for Catharine Rankin
# multiple profiles found for Catharine Rankin
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Alexander Rauscher
# multiple profiles found for Alexander Rauscher
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Lynn Raymond
# multiple profiles found for Lynn Raymond
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Heather Robertson
# multiple profiles found for Heather Robertson
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# looking at profile 3
# subject and location match found
# updating best match
#
#
# searching for Julie Robillard
# multiple profiles found for Julie Robillard
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Jessica Rosin
# multiple profiles found for Jessica Rosin
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
#
#
# searching for Jane Roskams
# multiple profiles found for Jane Roskams
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
#
#
# searching for Christian Schütz
# multiple profiles found for Christian Schütz
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Jeremy Seamans
#
#
# searching for Mypinder Sekhon
#
#
# searching for Noah Silverberg
#
#
# searching for Terry Snutch
#
#
# searching for Jason Snyder
# multiple profiles found for Jason Snyder
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Kiran Soma
# multiple profiles found for Kiran Soma
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Weihong Song
# multiple profiles found for Weihong Song
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Vesna Sossi
#
#
# searching for Miriam Spering
#
#
# searching for Evelyn Stewart
# multiple profiles found for Evelyn Stewart
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Jon Stoessl
# multiple profiles found for Jon Stoessl
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Robert Stowe
# multiple profiles found for Robert Stowe
# looking at profile 0
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Sriram Subramaniam
# multiple profiles found for Sriram Subramaniam
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Roger Tam
# multiple profiles found for Roger Tam
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Wolfram Tetzlaff
#
#
# searching for Rebecca Todd
# multiple profiles found for Rebecca Todd
# looking at profile 0
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Tony Traboulsee
#
#
# searching for Helen Tremlett
#
#
# searching for Tamara Vanderwal
#
#
# searching for Paul van Donkelaar
# multiple profiles found for Paul van Donkelaar
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Victor Viau
#
#
# searching for Daniel Vigo
# multiple profiles found for Daniel Vigo
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Carles Vilarino-Guell
# multiple profiles found for Carles Vilarino-Guell
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Fidel Vila-Rodriguez
#
#
# searching for Naznin Virji-Babul
#
#
# searching for Yu Tian Wang
# multiple profiles found for Yu Tian Wang
# looking at profile 0
# looking at profile 1
# subject match found
# updating best match
# looking at profile 2
# looking at profile 3
# looking at profile 4
# looking at profile 5
# looking at profile 6
# looking at profile 7
# looking at profile 8
# looking at profile 9
# looking at profile 10
# looking at profile 11
# looking at profile 12
# looking at profile 13
# looking at profile 14
# looking at profile 15
# looking at profile 16
# looking at profile 17
# looking at profile 18
# looking at profile 19
# looking at profile 20
# looking at profile 21
# looking at profile 22
# subject and location match found
# updating best match
#
#
# searching for Lawrence Ward
# multiple profiles found for Lawrence Ward
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Alexander Weber
# multiple profiles found for Alexander Weber
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# looking at profile 2
# looking at profile 3
# looking at profile 4
# subject and location match found
# updating best match
#
#
# searching for Cheryl Wellington
# multiple profiles found for Cheryl Wellington
# looking at profile 0
# subject and location match found
# updating best match
#
#
# searching for Janet Werker
#
#
# searching for Christopher West
# multiple profiles found for Christopher West
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Catharine Winstanley
# multiple profiles found for Catharine Winstanley
# looking at profile 0
# subject match found
# updating best match
# looking at profile 1
# subject and location match found
# updating best match
#
#
# searching for Todd Woodward
#
#
# searching for Lakshmi Yatham

# %%
out_dict = {
    "Last Name": last_names,
    "First Name": first_names,
    "Affiliation": affils,
    "Scopus Author ID": auth_ids,
    "ORCID": orcids,
    "Tags": tags,
    "Research Areas": subjects,
    "Warnings": warnings,
}
print(no_search_results)

for key in out_dict:
    print(len(out_dict[key]))
# Out:
# [['Altshuler', 'Doug', 'Full', '', '', '', 'Primary', '', '1', '', '', 'https://scholar.google.com/citations?hl=en&user=EVACejsAAAAJ']]
# 128
# 128
# 128
# 128
# 128
# 128
# 128
# 128

# %%
df = pd.DataFrame.from_dict(out_dict)
df.to_csv(OUTPUT_FILEPATH)

# %% [markdown]
# use API to look through the any particular profiles if needed

# %%
# !!! modify lastname and firstname
lastname = "West"
firstname = "Christopher"

# %%
query = f"authlastname({lastname}) and authfirst({firstname})"
data = get_api_json(query, start=0)
print(data)
# Out:
# {'service-error': {'status': {'statusCode': 'AUTHORIZATION_ERROR', 'statusText': 'The requestor is not authorized to access the requested view or fields of the resource'}}}

# %%
print(int(data["search-results"]['opensearch:totalResults']))

for i in range(int(data["search-results"]['opensearch:totalResults'])):
    print("profile "+str(i))
    try:
        print(data["search-results"]["entry"][i]["preferred-name"])
        print("author ID: " + data["search-results"]["entry"][i]["dc:identifier"].split(":")[1])
        print("affiliation: " + str(data["search-results"]["entry"][i]["affiliation-current"]['affiliation-name']))
        print("subjects: " + str(data["search-results"]["entry"][i]["subject-area"]))
        print(any([x in str(data["search-results"]["entry"][i]["subject-area"]) for x in subjects_list]))
    except:
        print("info incomplete")
    
    print("\n")
