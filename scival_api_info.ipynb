# %%
### necessary for accessing APIs through python
import requests
import json

### preferred but optional

# delay in between API calls if many requests will be made
from time import sleep 

# to keep API key secure
# import os
# from dotenv import load_dotenv 
# load_dotenv()

# %% [markdown]
# API components:
# - endpoint: url for a specific resource
# - parameters: variables passed to an API endpoint
# - request headers: key-value pairs for additional information, such as authorization
# - request body: data necessary to create/update/delete a resource in the database (SciVal APIs only support "get" operations, so this is not used here)
# - API key: used for authentication, identifying the API user
#
# API response components:
# - status code: number for the status of a request, usually standardized
# - response header: provides additional information about server's response
# - response body: content returned by server

# %%
'''
SciVal API keys: https://dev.elsevier.com/apikey/manage (key with "citations" label has access to Citations Overview API, which is otherwise restricted)

SciVal Author Search API definitions (where you can find API endpoint, request headers information): https://dev.elsevier.com/documentation/AuthorSearchAPI.wadl

SciVal Author Search API guide (specific parameters for the request body/query): https://dev.elsevier.com/sc_author_search_tips.html
'''

### url of API endpoint
# Author Search API
url = "http://api.elsevier.com/content/search/author"

### populate headers (look for "required" fields)

# if
# api_key = os.getenv("API_KEY")
api_key = "2e5922c95a0e4f1fb73cede25eca779a"

headers = {
    "Accept": "application/json",
    "X-ELS-APIKey": api_key,
}

### populate params
# Author Search API
lastname = "West"
firstname = "Christopher"
params = {
    "query": f"authlastname({lastname}) and authfirst({firstname})"
}

# %%
response = requests.get(url=url,
                        params=params, 
                        headers=headers)
data = json.loads(response.text)
print(data)
# Out:
# {'search-results': {'opensearch:totalResults': '44', 'opensearch:startIndex': '0', 'opensearch:itemsPerPage': '25', 'opensearch:Query': {'@role': 'request', '@searchTerms': 'authlastname(West) and authfirst(Christopher)', '@startPage': '0'}, 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/search/author?start=0&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29', '@type': 'application/json'}, {'@_fa': 'true', '@ref': 'first', '@href': 'https://api.elsevier.com/content/search/author?start=0&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29', '@type': 'application/json'}, {'@_fa': 'true', '@ref': 'next', '@href': 'https://api.elsevier.com/content/search/author?start=25&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29', '@type': 'application/json'}, {'@_fa': 'true', '@ref': 'last', '@href': 'https://api.elsevier.com/content/search/author?start=19&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29', '@type': 'application/json'}], 'entry': [{'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/author/author_id/7402187736'}, {'@_fa': 'true', '@ref': 'search', '@href': 'https://api.elsevier.com/content/search/author?query=au-id%287402187736%29'}, {'@_fa': 'true', '@ref': 'scopus-citedby', '@href': 'https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=7402187736&origin=inward'}, {'@_fa': 'true', '@ref': 'scopus-author', '@href': 'https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=7402187736&origin=inward'}], 'prism:url': 'https://api.elsevier.com/content/author/author_id/7402187736', 'dc:identifier': 'AUTHOR_ID:7402187736', 'eid': '9-s2.0-7402187736', 'preferred-name': {'surname': 'West', 'given-name': 'Christopher M.', 'initials': 'C.M.'}, 'name-variant': [{'@_fa': 'true', 'surname': 'M. West', 'given-name': 'Christopher', 'initials': 'C.'}, {'@_fa': 'true', 'surname': 'West', 'given-name': 'C. M.', 'initials': 'C.M.'}, {'@_fa': 'true', 'surname': 'West', 'given-name': 'C.', 'initials': 'C.'}], 'document-count': '122', 'subject-area': [{'@abbrev': 'BIOC', '@frequency': '261', '$': 'Biochemistry, Genetics and Molecular Biology (all)'}, {'@abbrev': 'MEDI', '@frequency': '56', '$': 'Medicine (all)'}, {'@abbrev': 'IMMU', '@frequency': '25', '$': 'Immunology and Microbiology (all)'}], 'affiliation-current': {'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60029747', 'affiliation-id': '60029747', 'affiliation-name': 'University of Georgia', 'affiliation-city': 'Athens', 'affiliation-country': 'United States'}}, {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/author/author_id/56232410100'}, {'@_fa': 'true', '@ref': 'search', '@href': 'https://api.elsevier.com/content/search/author?query=au-id%2856232410100%29'}, {'@_fa': 'true', '@ref': 'scopus-citedby', '@href': 'https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56232410100&origin=inward'}, {'@_fa': 'true', '@ref': 'scopus-author', '@href': 'https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410100&origin=inward'}], 'prism:url': 'https://api.elsevier.com/content/author/author_id/56232410100', 'dc:identifier': 'AUTHOR_ID:56232410100', 'eid': '9-s2.0-56232410100', 'preferred-name': {'surname': 'West', 'given-name': 'Christopher R.', 'initials': 'C.R.'}, 'name-variant': [{'@_fa': 'true', 'surname': 'West', 'given-name': 'Christopher R.', 'initials': 'C.R.'}, {'@_fa': 'true', 'surname': 'West', 'given-name': 'C.', 'initials': 'C.'}, {'@_fa': 'true', 'surname': 'West', 'given-name': 'Chris', 'initials': 'C.'}], 'document-count': '91', 'subject-area': [{'@abbrev': 'MEDI', '@frequency': '143', '$': 'Medicine (all)'}, {'@abbrev': 'BIOC', '@frequency': '27', '$': 'Biochemistry, Genetics and Molecular Biology (all)'}, {'@abbrev': 'NEUR', '@frequency': '25', '$': 'Neuroscie ...

# %%
# view data as a formatted string
data_str = json.dumps(data, indent=4)
print(data_str)
# Out:
# {
#     "search-results": {
#         "opensearch:totalResults": "44",
#         "opensearch:startIndex": "0",
#         "opensearch:itemsPerPage": "25",
#         "opensearch:Query": {
#             "@role": "request",
#             "@searchTerms": "authlastname(West) and authfirst(Christopher)",
#             "@startPage": "0"
#         },
#         "link": [
#             {
#                 "@_fa": "true",
#                 "@ref": "self",
#                 "@href": "https://api.elsevier.com/content/search/author?start=0&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#                 "@type": "application/json"
#             },
#             {
#                 "@_fa": "true",
#                 "@ref": "first",
#                 "@href": "https://api.elsevier.com/content/search/author?start=0&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#                 "@type": "application/json"
#             },
#             {
#                 "@_fa": "true",
#                 "@ref": "next",
#                 "@href": "https://api.elsevier.com/content/search/author?start=25&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#                 "@type": "application/json"
#             },
#             {
#                 "@_fa": "true",
#                 "@ref": "last",
#                 "@href": "https://api.elsevier.com/content/search/author?start=19&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#                 "@type": "application/json"
#             }
#         ],
#         "entry": [
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/7402187736"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%287402187736%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=7402187736&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=7402187736&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/7402187736",
#                 "dc:identifier": "AUTHOR_ID:7402187736",
#                 "eid": "9-s2.0-7402187736",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher M.",
#                     "initials": "C.M."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "M. West",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C. M.",
#                         "initials": "C.M."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C.",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "122",
#                 "subject-area": [
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "261",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "56",
#                         "$": "Medicine (all)"
#                     },
#                     {
#                         "@abbrev": "IMMU",
#                         "@frequency": "25",
#                         "$": "Immunology and Microbiology (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60029747",
#                     "affiliation-id": "60029747",
#                     "affiliation-name": "University of Georgia",
#                     "affiliation-city": "Athens",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/56232410100"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856232410100%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56232410100&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410100&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/56232410100",
#                 "dc:identifier": "AUTHOR_ID:56232410100",
#                 "eid": "9-s2.0-56232410100",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher R.",
#                     "initials": "C.R."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher R.",
#                         "initials": "C.R."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C.",
#                         "initials": "C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "91",
#                 "subject-area": [
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "143",
#                         "$": "Medicine (all)"
#                     },
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "27",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "NEUR",
#                         "@frequency": "25",
#                         "$": "Neuroscience (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60023077",
#                     "affiliation-id": "60023077",
#                     "affiliation-name": "University of British Columbia, Faculty of Medicine",
#                     "affiliation-city": "Vancouver",
#                     "affiliation-country": "Canada"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57209151783"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857209151783%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57209151783&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57209151783&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57209151783",
#                 "dc:identifier": "AUTHOR_ID:57209151783",
#                 "eid": "9-s2.0-57209151783",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher Robert",
#                     "initials": "C.R."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "WEST",
#                         "given-name": "C. R.",
#                         "initials": "C.R."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher R.",
#                         "initials": "C.R."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "72",
#                 "subject-area": [
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "113",
#                         "$": "Medicine (all)"
#                     },
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "24",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "PHAR",
#                         "@frequency": "8",
#                         "$": "Pharmacology, Toxicology and Pharmaceutics (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60020661",
#                     "affiliation-id": "60020661",
#                     "affiliation-name": "University of Liverpool",
#                     "affiliation-city": "Liverpool",
#                     "affiliation-country": "United Kingdom"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/25223111300"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2825223111300%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=25223111300&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=25223111300&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/25223111300",
#                 "dc:identifier": "AUTHOR_ID:25223111300",
#                 "eid": "9-s2.0-25223111300",
#                 "orcid": "0000-0002-5609-2237",
#                 "preferred-name": {
#                     "surname": "Hamilton-West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "Christopher Hamilton-West",
#                         "given-name": "M.",
#                         "initials": "M."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "Hamilton-West",
#                         "given-name": "C.",
#                         "initials": "C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "Hamilton-west",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "44",
#                 "subject-area": [
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "50",
#                         "$": "Medicine (all)"
#                     },
#                     {
#                         "@abbrev": "AGRI",
#                         "@frequency": "27",
#                         "$": "Agricultural and Biological Sciences (all)"
#                     },
#                     {
#                         "@abbrev": "VETE",
#                         "@frequency": "26",
#                         "$": "Veterinary (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60012464",
#                     "affiliation-id": "60012464",
#                     "affiliation-name": "Universidad de Chile",
#                     "affiliation-city": "Santiago",
#                     "affiliation-country": "Chile"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/55777163700"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2855777163700%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55777163700&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55777163700&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/55777163700",
#                 "dc:identifier": "AUTHOR_ID:55777163700",
#                 "eid": "9-s2.0-55777163700",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher C.",
#                     "initials": "C.C."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris C.",
#                         "initials": "C.C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris",
#                         "initials": "C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "38",
#                 "subject-area": [
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "70",
#                         "$": "Medicine (all)"
#                     },
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "33",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "MATE",
#                         "@frequency": "5",
#                         "$": "Materials Science (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60014873",
#                     "affiliation-id": "60014873",
#                     "affiliation-name": "University of Edinburgh, MRC Centre for Regenerative Medicine",
#                     "affiliation-city": "Edinburgh",
#                     "affiliation-country": "United Kingdom"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57210969623"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857210969623%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57210969623&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57210969623&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57210969623",
#                 "dc:identifier": "AUTHOR_ID:57210969623",
#                 "eid": "9-s2.0-57210969623",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher E.",
#                     "initials": "C.E."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C. E.",
#                         "initials": "C.E."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris E.",
#                         "initials": "C.E."
#                     }
#                 ],
#                 "document-count": "35",
#                 "subject-area": [
#                     {
#                         "@abbrev": "AGRI",
#                         "@frequency": "34",
#                         "$": "Agricultural and Biological Sciences (all)"
#                     },
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "34",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "9",
#                         "$": "Medicine (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60012070",
#                     "affiliation-id": "60012070",
#                     "affiliation-name": "University of Leeds",
#                     "affiliation-city": "Leeds",
#                     "affiliation-country": "United Kingdom"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/56763374400"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856763374400%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56763374400&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56763374400&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/56763374400",
#                 "dc:identifier": "AUTHOR_ID:56763374400",
#                 "eid": "9-s2.0-56763374400",
#                 "orcid": "0000-0002-5091-6514",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Chris D.",
#                     "initials": "C.D."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher D.",
#                         "initials": "C.D."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris D.",
#                         "initials": "C.D."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "27",
#                 "subject-area": [
#                     {
#                         "@abbrev": "ENVI",
#                         "@frequency": "35",
#                         "$": "Environmental Science (all)"
#                     },
#                     {
#                         "@abbrev": "SOCI",
#                         "@frequency": "10",
#                         "$": "Social Sciences (all)"
#                     },
#                     {
#                         "@abbrev": "ENER",
#                         "@frequency": "8",
#                         "$": "Energy (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60016418",
#                     "affiliation-id": "60016418",
#                     "affiliation-name": "University of York",
#                     "affiliation-city": "York",
#                     "affiliation-country": "United Kingdom"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/56719058800"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856719058800%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56719058800&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56719058800&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/56719058800",
#                 "dc:identifier": "AUTHOR_ID:56719058800",
#                 "eid": "9-s2.0-56719058800",
#                 "orcid": "0000-0003-1193-0986",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher K.",
#                     "initials": "C.K."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher K.",
#                         "initials": "C.K."
#                     }
#                 ],
#                 "document-count": "19",
#                 "subject-area": [
#                     {
#                         "@abbrev": "EART",
#                         "@frequency": "31",
#                         "$": "Earth and Planetary Sciences (all)"
#                     },
#                     {
#                         "@abbrev": "AGRI",
#                         "@frequency": "8",
#                         "$": "Agricultural and Biological Sciences (all)"
#                     },
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "1",
#                         "$": "Medicine (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60030835",
#                     "affiliation-id": "60030835",
#                     "affiliation-name": "University of Alberta",
#                     "affiliation-city": "Edmonton",
#                     "affiliation-country": "Canada"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/55843206800"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2855843206800%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55843206800&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55843206800&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/55843206800",
#                 "dc:identifier": "AUTHOR_ID:55843206800",
#                 "eid": "9-s2.0-55843206800",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher W.",
#                     "initials": "C.W."
#                 },
#                 "document-count": "19",
#                 "subject-area": [
#                     {
#                         "@abbrev": "CHEM",
#                         "@frequency": "16",
#                         "$": "Chemistry (all)"
#                     },
#                     {
#                         "@abbrev": "PHYS",
#                         "@frequency": "11",
#                         "$": "Physics and Astronomy (all)"
#                     },
#                     {
#                         "@abbrev": "MATE",
#                         "@frequency": "6",
#                         "$": "Materials Science (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60011001",
#                     "affiliation-id": "60011001",
#                     "affiliation-name": "Kyoto University",
#                     "affiliation-city": "Kyoto",
#                     "affiliation-country": "Japan"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/7402188605"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%287402188605%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=7402188605&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=7402188605&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/7402188605",
#                 "dc:identifier": "AUTHOR_ID:7402188605",
#                 "eid": "9-s2.0-7402188605",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher L.",
#                     "initials": "C.L."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C. L.",
#                         "initials": "C.L."
#                     }
#                 ],
#                 "document-count": "14",
#                 "subject-area": [
#                     {
#                         "@abbrev": "ENGI",
#                         "@frequency": "12",
#                         "$": "Engineering (all)"
#                     },
#                     {
#                         "@abbrev": "PHYS",
#                         "@frequency": "3",
#                         "$": "Physics and Astronomy (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60026242",
#                     "affiliation-id": "60026242",
#                     "affiliation-name": "Defence Science and Technology Laboratory",
#                     "affiliation-city": "Salisbury",
#                     "affiliation-country": "United Kingdom"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/8707935900"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%288707935900%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=8707935900&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=8707935900&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/8707935900",
#                 "dc:identifier": "AUTHOR_ID:8707935900",
#                 "eid": "9-s2.0-8707935900",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher J.",
#                     "initials": "C.J."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C.",
#                         "initials": "C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C. J.",
#                         "initials": "C.J."
#                     }
#                 ],
#                 "document-count": "13",
#                 "subject-area": [
#                     {
#                         "@abbrev": "AGRI",
#                         "@frequency": "14",
#                         "$": "Agricultural and Biological Sciences (all)"
#                     },
#                     {
#                         "@abbrev": "VETE",
#                         "@frequency": "6",
#                         "$": "Veterinary (all)"
#                     },
#                     {
#                         "@abbrev": "IMMU",
#                         "@frequency": "3",
#                         "$": "Immunology and Microbiology (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60032306",
#                     "affiliation-id": "60032306",
#                     "affiliation-name": "AgResearch Grasslands",
#                     "affiliation-city": "Palmerston North",
#                     "affiliation-country": "New Zealand"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/55711289900"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2855711289900%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55711289900&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55711289900&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/55711289900",
#                 "dc:identifier": "AUTHOR_ID:55711289900",
#                 "eid": "9-s2.0-55711289900",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Alexander Christopher",
#                     "initials": "A.C."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Alexander C.",
#                         "initials": "A.C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "A.",
#                         "initials": "A."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Alexander",
#                         "initials": "A."
#                     }
#                 ],
#                 "document-count": "12",
#                 "subject-area": [
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "14",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "13",
#                         "$": "Medicine (all)"
#                     },
#                     {
#                         "@abbrev": "AGRI",
#                         "@frequency": "9",
#                         "$": "Agricultural and Biological Sciences (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60021255",
#                     "affiliation-id": "60021255",
#                     "affiliation-name": "UiT Norges Arktiske Universitet",
#                     "affiliation-city": "Tromso",
#                     "affiliation-country": "Norway"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57218339832"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857218339832%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57218339832&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57218339832&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57218339832",
#                 "dc:identifier": "AUTHOR_ID:57218339832",
#                 "eid": "9-s2.0-57218339832",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher P.C.P.",
#                     "initials": "C.P.C.P."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C. P.C.P.",
#                         "initials": "C.P.C.P."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher P.",
#                         "initials": "C.P."
#                     }
#                 ],
#                 "document-count": "10",
#                 "subject-area": [
#                     {
#                         "@abbrev": "ENVI",
#                         "@frequency": "10",
#                         "$": "Environmental Science (all)"
#                     },
#                     {
#                         "@abbrev": "CHEM",
#                         "@frequency": "6",
#                         "$": "Chemistry (all)"
#                     },
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "6",
#                         "$": "Medicine (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60028629",
#                     "affiliation-id": "60028629",
#                     "affiliation-name": "College of Science",
#                     "affiliation-city": "West Lafayette",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57213445762"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857213445762%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57213445762&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57213445762&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57213445762",
#                 "dc:identifier": "AUTHOR_ID:57213445762",
#                 "eid": "9-s2.0-57213445762",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher J.",
#                     "initials": "C.J."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C.",
#                         "initials": "C."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "9",
#                 "subject-area": [
#                     {
#                         "@abbrev": "PHYS",
#                         "@frequency": "11",
#                         "$": "Physics and Astronomy (all)"
#                     },
#                     {
#                         "@abbrev": "EART",
#                         "@frequency": "7",
#                         "$": "Earth and Planetary Sciences (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60028787",
#                     "affiliation-id": "60028787",
#                     "affiliation-name": "Macalester College",
#                     "affiliation-city": "Minneapolis",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57198881202"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857198881202%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57198881202&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57198881202&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57198881202",
#                 "dc:identifier": "AUTHOR_ID:57198881202",
#                 "eid": "9-s2.0-57198881202",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher D.",
#                     "initials": "C.D."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "C.",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "7",
#                 "subject-area": [
#                     {
#                         "@abbrev": "NEUR",
#                         "@frequency": "7",
#                         "$": "Neuroscience (all)"
#                     },
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "6",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "2",
#                         "$": "Medicine (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60006385",
#                     "affiliation-id": "60006385",
#                     "affiliation-name": "Boston University School of Medicine",
#                     "affiliation-city": "Boston",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/56008583500"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856008583500%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
# ...
#                     "affiliation-city": "Dayton",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/15838351300"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2815838351300%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=15838351300&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=15838351300&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/15838351300",
#                 "dc:identifier": "AUTHOR_ID:15838351300",
#                 "eid": "9-s2.0-15838351300",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher E.",
#                     "initials": "C.E."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "5",
#                 "subject-area": [
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "5",
#                         "$": "Medicine (all)"
#                     },
#                     {
#                         "@abbrev": "HEAL",
#                         "@frequency": "2",
#                         "$": "Health Professions  (all)"
#                     },
#                     {
#                         "@abbrev": "SOCI",
#                         "@frequency": "2",
#                         "$": "Social Sciences (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60023691",
#                     "affiliation-id": "60023691",
#                     "affiliation-name": "University of California, San Francisco",
#                     "affiliation-city": "San Francisco",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57198881210"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857198881210%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57198881210&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57198881210&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57198881210",
#                 "dc:identifier": "AUTHOR_ID:57198881210",
#                 "eid": "9-s2.0-57198881210",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher W.",
#                     "initials": "C.W."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "4",
#                 "subject-area": [
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "17",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "PHAR",
#                         "@frequency": "4",
#                         "$": "Pharmacology, Toxicology and Pharmaceutics (all)"
#                     },
#                     {
#                         "@abbrev": "CHEM",
#                         "@frequency": "3",
#                         "$": "Chemistry (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60006680",
#                     "affiliation-id": "60006680",
#                     "affiliation-name": "Bayer AG",
#                     "affiliation-city": "Leverkusen",
#                     "affiliation-country": "Germany"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/58350386400"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2858350386400%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=58350386400&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=58350386400&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/58350386400",
#                 "dc:identifier": "AUTHOR_ID:58350386400",
#                 "eid": "9-s2.0-58350386400",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Chris",
#                     "initials": "C."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "3",
#                 "subject-area": [
#                     {
#                         "@abbrev": "ENGI",
#                         "@frequency": "2",
#                         "$": "Engineering (all)"
#                     },
#                     {
#                         "@abbrev": "PHYS",
#                         "@frequency": "2",
#                         "$": "Physics and Astronomy (all)"
#                     },
#                     {
#                         "@abbrev": "MULT",
#                         "@frequency": "1",
#                         "$": "Multidisciplinary"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60025590",
#                     "affiliation-id": "60025590",
#                     "affiliation-name": "SLAC National Accelerator Laboratory",
#                     "affiliation-city": "Menlo Park",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57221673643"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857221673643%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57221673643&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57221673643&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57221673643",
#                 "dc:identifier": "AUTHOR_ID:57221673643",
#                 "eid": "9-s2.0-57221673643",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 },
#                 "document-count": "3",
#                 "subject-area": [
#                     {
#                         "@abbrev": "BIOC",
#                         "@frequency": "4",
#                         "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                     },
#                     {
#                         "@abbrev": "MEDI",
#                         "@frequency": "3",
#                         "$": "Medicine (all)"
#                     }
#                 ],
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60024724",
#                     "affiliation-id": "60024724",
#                     "affiliation-name": "University of Strathclyde",
#                     "affiliation-city": "Glasgow",
#                     "affiliation-country": "United Kingdom"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/57202115454"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857202115454%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57202115454&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57202115454&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/57202115454",
#                 "dc:identifier": "AUTHOR_ID:57202115454",
#                 "eid": "9-s2.0-57202115454",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher R.",
#                     "initials": "C.R."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher R.",
#                         "initials": "C.R."
#                     },
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Christopher",
#                         "initials": "C."
#                     }
#                 ],
#                 "document-count": "3",
#                 "subject-area": {
#                     "@abbrev": "MEDI",
#                     "@frequency": "1",
#                     "$": "Medicine (all)"
#                 },
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60024324",
#                     "affiliation-id": "60024324",
#                     "affiliation-name": "University of Iowa",
#                     "affiliation-city": "Iowa City",
#                     "affiliation-country": "United States"
#                 }
#             },
#             {
#                 "@_fa": "true",
#                 "link": [
#                     {
#                         "@_fa": "true",
#                         "@ref": "self",
#                         "@href": "https://api.elsevier.com/content/author/author_id/56232410600"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "search",
#                         "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856232410600%29"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-citedby",
#                         "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56232410600&origin=inward"
#                     },
#                     {
#                         "@_fa": "true",
#                         "@ref": "scopus-author",
#                         "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410600&origin=inward"
#                     }
#                 ],
#                 "prism:url": "https://api.elsevier.com/content/author/author_id/56232410600",
#                 "dc:identifier": "AUTHOR_ID:56232410600",
#                 "eid": "9-s2.0-56232410600",
#                 "preferred-name": {
#                     "surname": "West",
#                     "given-name": "Christopher W.",
#                     "initials": "C.W."
#                 },
#                 "name-variant": [
#                     {
#                         "@_fa": "true",
#                         "surname": "West",
#                         "given-name": "Chris W.",
#                         "initials": "C.W."
#                     }
#                 ],
#                 "document-count": "3",
#                 "subject-area": {
#                     "@abbrev": "BIOC",
#                     "@frequency": "3",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 "affiliation-current": {
#                     "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60032179",
#                     "affiliation-id": "60032179",
#                     "affiliation-name": "University of Wisconsin-Madison",
#                     "affiliation-city": "Madison",
#                     "affiliation-country": "United States"
#                 }
#             }
#         ]
#     }
# }

# %%
# go deeper into the json array
data_str = json.dumps(data["search-results"], indent=4)
print(data_str)
# Out:
# {
#     "opensearch:totalResults": "44",
#     "opensearch:startIndex": "0",
#     "opensearch:itemsPerPage": "25",
#     "opensearch:Query": {
#         "@role": "request",
#         "@searchTerms": "authlastname(West) and authfirst(Christopher)",
#         "@startPage": "0"
#     },
#     "link": [
#         {
#             "@_fa": "true",
#             "@ref": "self",
#             "@href": "https://api.elsevier.com/content/search/author?start=0&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#             "@type": "application/json"
#         },
#         {
#             "@_fa": "true",
#             "@ref": "first",
#             "@href": "https://api.elsevier.com/content/search/author?start=0&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#             "@type": "application/json"
#         },
#         {
#             "@_fa": "true",
#             "@ref": "next",
#             "@href": "https://api.elsevier.com/content/search/author?start=25&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#             "@type": "application/json"
#         },
#         {
#             "@_fa": "true",
#             "@ref": "last",
#             "@href": "https://api.elsevier.com/content/search/author?start=19&count=25&query=authlastname%28West%29+and+authfirst%28Christopher%29",
#             "@type": "application/json"
#         }
#     ],
#     "entry": [
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/7402187736"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%287402187736%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=7402187736&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=7402187736&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/7402187736",
#             "dc:identifier": "AUTHOR_ID:7402187736",
#             "eid": "9-s2.0-7402187736",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher M.",
#                 "initials": "C.M."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "M. West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C. M.",
#                     "initials": "C.M."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C.",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "122",
#             "subject-area": [
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "261",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "56",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "IMMU",
#                     "@frequency": "25",
#                     "$": "Immunology and Microbiology (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60029747",
#                 "affiliation-id": "60029747",
#                 "affiliation-name": "University of Georgia",
#                 "affiliation-city": "Athens",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/56232410100"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856232410100%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56232410100&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410100&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/56232410100",
#             "dc:identifier": "AUTHOR_ID:56232410100",
#             "eid": "9-s2.0-56232410100",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher R.",
#                 "initials": "C.R."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher R.",
#                     "initials": "C.R."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C.",
#                     "initials": "C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "91",
#             "subject-area": [
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "143",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "27",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "NEUR",
#                     "@frequency": "25",
#                     "$": "Neuroscience (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60023077",
#                 "affiliation-id": "60023077",
#                 "affiliation-name": "University of British Columbia, Faculty of Medicine",
#                 "affiliation-city": "Vancouver",
#                 "affiliation-country": "Canada"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57209151783"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857209151783%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57209151783&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57209151783&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57209151783",
#             "dc:identifier": "AUTHOR_ID:57209151783",
#             "eid": "9-s2.0-57209151783",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher Robert",
#                 "initials": "C.R."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "WEST",
#                     "given-name": "C. R.",
#                     "initials": "C.R."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher R.",
#                     "initials": "C.R."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "72",
#             "subject-area": [
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "113",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "24",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "PHAR",
#                     "@frequency": "8",
#                     "$": "Pharmacology, Toxicology and Pharmaceutics (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60020661",
#                 "affiliation-id": "60020661",
#                 "affiliation-name": "University of Liverpool",
#                 "affiliation-city": "Liverpool",
#                 "affiliation-country": "United Kingdom"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/25223111300"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2825223111300%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=25223111300&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=25223111300&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/25223111300",
#             "dc:identifier": "AUTHOR_ID:25223111300",
#             "eid": "9-s2.0-25223111300",
#             "orcid": "0000-0002-5609-2237",
#             "preferred-name": {
#                 "surname": "Hamilton-West",
#                 "given-name": "Christopher",
#                 "initials": "C."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "Christopher Hamilton-West",
#                     "given-name": "M.",
#                     "initials": "M."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "Hamilton-West",
#                     "given-name": "C.",
#                     "initials": "C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "Hamilton-west",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "44",
#             "subject-area": [
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "50",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "AGRI",
#                     "@frequency": "27",
#                     "$": "Agricultural and Biological Sciences (all)"
#                 },
#                 {
#                     "@abbrev": "VETE",
#                     "@frequency": "26",
#                     "$": "Veterinary (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60012464",
#                 "affiliation-id": "60012464",
#                 "affiliation-name": "Universidad de Chile",
#                 "affiliation-city": "Santiago",
#                 "affiliation-country": "Chile"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/55777163700"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2855777163700%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55777163700&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55777163700&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/55777163700",
#             "dc:identifier": "AUTHOR_ID:55777163700",
#             "eid": "9-s2.0-55777163700",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher C.",
#                 "initials": "C.C."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris C.",
#                     "initials": "C.C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris",
#                     "initials": "C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "38",
#             "subject-area": [
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "70",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "33",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "MATE",
#                     "@frequency": "5",
#                     "$": "Materials Science (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60014873",
#                 "affiliation-id": "60014873",
#                 "affiliation-name": "University of Edinburgh, MRC Centre for Regenerative Medicine",
#                 "affiliation-city": "Edinburgh",
#                 "affiliation-country": "United Kingdom"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57210969623"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857210969623%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57210969623&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57210969623&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57210969623",
#             "dc:identifier": "AUTHOR_ID:57210969623",
#             "eid": "9-s2.0-57210969623",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher E.",
#                 "initials": "C.E."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C. E.",
#                     "initials": "C.E."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris E.",
#                     "initials": "C.E."
#                 }
#             ],
#             "document-count": "35",
#             "subject-area": [
#                 {
#                     "@abbrev": "AGRI",
#                     "@frequency": "34",
#                     "$": "Agricultural and Biological Sciences (all)"
#                 },
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "34",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "9",
#                     "$": "Medicine (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60012070",
#                 "affiliation-id": "60012070",
#                 "affiliation-name": "University of Leeds",
#                 "affiliation-city": "Leeds",
#                 "affiliation-country": "United Kingdom"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/56763374400"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856763374400%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56763374400&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56763374400&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/56763374400",
#             "dc:identifier": "AUTHOR_ID:56763374400",
#             "eid": "9-s2.0-56763374400",
#             "orcid": "0000-0002-5091-6514",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Chris D.",
#                 "initials": "C.D."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher D.",
#                     "initials": "C.D."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris D.",
#                     "initials": "C.D."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "27",
#             "subject-area": [
#                 {
#                     "@abbrev": "ENVI",
#                     "@frequency": "35",
#                     "$": "Environmental Science (all)"
#                 },
#                 {
#                     "@abbrev": "SOCI",
#                     "@frequency": "10",
#                     "$": "Social Sciences (all)"
#                 },
#                 {
#                     "@abbrev": "ENER",
#                     "@frequency": "8",
#                     "$": "Energy (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60016418",
#                 "affiliation-id": "60016418",
#                 "affiliation-name": "University of York",
#                 "affiliation-city": "York",
#                 "affiliation-country": "United Kingdom"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/56719058800"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856719058800%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56719058800&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56719058800&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/56719058800",
#             "dc:identifier": "AUTHOR_ID:56719058800",
#             "eid": "9-s2.0-56719058800",
#             "orcid": "0000-0003-1193-0986",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher K.",
#                 "initials": "C.K."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher K.",
#                     "initials": "C.K."
#                 }
#             ],
#             "document-count": "19",
#             "subject-area": [
#                 {
#                     "@abbrev": "EART",
#                     "@frequency": "31",
#                     "$": "Earth and Planetary Sciences (all)"
#                 },
#                 {
#                     "@abbrev": "AGRI",
#                     "@frequency": "8",
#                     "$": "Agricultural and Biological Sciences (all)"
#                 },
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "1",
#                     "$": "Medicine (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60030835",
#                 "affiliation-id": "60030835",
#                 "affiliation-name": "University of Alberta",
#                 "affiliation-city": "Edmonton",
#                 "affiliation-country": "Canada"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/55843206800"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2855843206800%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55843206800&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55843206800&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/55843206800",
#             "dc:identifier": "AUTHOR_ID:55843206800",
#             "eid": "9-s2.0-55843206800",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher W.",
#                 "initials": "C.W."
#             },
#             "document-count": "19",
#             "subject-area": [
#                 {
#                     "@abbrev": "CHEM",
#                     "@frequency": "16",
#                     "$": "Chemistry (all)"
#                 },
#                 {
#                     "@abbrev": "PHYS",
#                     "@frequency": "11",
#                     "$": "Physics and Astronomy (all)"
#                 },
#                 {
#                     "@abbrev": "MATE",
#                     "@frequency": "6",
#                     "$": "Materials Science (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60011001",
#                 "affiliation-id": "60011001",
#                 "affiliation-name": "Kyoto University",
#                 "affiliation-city": "Kyoto",
#                 "affiliation-country": "Japan"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/7402188605"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%287402188605%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=7402188605&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=7402188605&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/7402188605",
#             "dc:identifier": "AUTHOR_ID:7402188605",
#             "eid": "9-s2.0-7402188605",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher L.",
#                 "initials": "C.L."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C. L.",
#                     "initials": "C.L."
#                 }
#             ],
#             "document-count": "14",
#             "subject-area": [
#                 {
#                     "@abbrev": "ENGI",
#                     "@frequency": "12",
#                     "$": "Engineering (all)"
#                 },
#                 {
#                     "@abbrev": "PHYS",
#                     "@frequency": "3",
#                     "$": "Physics and Astronomy (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60026242",
#                 "affiliation-id": "60026242",
#                 "affiliation-name": "Defence Science and Technology Laboratory",
#                 "affiliation-city": "Salisbury",
#                 "affiliation-country": "United Kingdom"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/8707935900"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%288707935900%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=8707935900&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=8707935900&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/8707935900",
#             "dc:identifier": "AUTHOR_ID:8707935900",
#             "eid": "9-s2.0-8707935900",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher J.",
#                 "initials": "C.J."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C.",
#                     "initials": "C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C. J.",
#                     "initials": "C.J."
#                 }
#             ],
#             "document-count": "13",
#             "subject-area": [
#                 {
#                     "@abbrev": "AGRI",
#                     "@frequency": "14",
#                     "$": "Agricultural and Biological Sciences (all)"
#                 },
#                 {
#                     "@abbrev": "VETE",
#                     "@frequency": "6",
#                     "$": "Veterinary (all)"
#                 },
#                 {
#                     "@abbrev": "IMMU",
#                     "@frequency": "3",
#                     "$": "Immunology and Microbiology (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60032306",
#                 "affiliation-id": "60032306",
#                 "affiliation-name": "AgResearch Grasslands",
#                 "affiliation-city": "Palmerston North",
#                 "affiliation-country": "New Zealand"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/55711289900"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2855711289900%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55711289900&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55711289900&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/55711289900",
#             "dc:identifier": "AUTHOR_ID:55711289900",
#             "eid": "9-s2.0-55711289900",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Alexander Christopher",
#                 "initials": "A.C."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Alexander C.",
#                     "initials": "A.C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "A.",
#                     "initials": "A."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Alexander",
#                     "initials": "A."
#                 }
#             ],
#             "document-count": "12",
#             "subject-area": [
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "14",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "13",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "AGRI",
#                     "@frequency": "9",
#                     "$": "Agricultural and Biological Sciences (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60021255",
#                 "affiliation-id": "60021255",
#                 "affiliation-name": "UiT Norges Arktiske Universitet",
#                 "affiliation-city": "Tromso",
#                 "affiliation-country": "Norway"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57218339832"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857218339832%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57218339832&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57218339832&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57218339832",
#             "dc:identifier": "AUTHOR_ID:57218339832",
#             "eid": "9-s2.0-57218339832",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher P.C.P.",
#                 "initials": "C.P.C.P."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C. P.C.P.",
#                     "initials": "C.P.C.P."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher P.",
#                     "initials": "C.P."
#                 }
#             ],
#             "document-count": "10",
#             "subject-area": [
#                 {
#                     "@abbrev": "ENVI",
#                     "@frequency": "10",
#                     "$": "Environmental Science (all)"
#                 },
#                 {
#                     "@abbrev": "CHEM",
#                     "@frequency": "6",
#                     "$": "Chemistry (all)"
#                 },
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "6",
#                     "$": "Medicine (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60028629",
#                 "affiliation-id": "60028629",
#                 "affiliation-name": "College of Science",
#                 "affiliation-city": "West Lafayette",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57213445762"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857213445762%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57213445762&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57213445762&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57213445762",
#             "dc:identifier": "AUTHOR_ID:57213445762",
#             "eid": "9-s2.0-57213445762",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher J.",
#                 "initials": "C.J."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C.",
#                     "initials": "C."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "9",
#             "subject-area": [
#                 {
#                     "@abbrev": "PHYS",
#                     "@frequency": "11",
#                     "$": "Physics and Astronomy (all)"
#                 },
#                 {
#                     "@abbrev": "EART",
#                     "@frequency": "7",
#                     "$": "Earth and Planetary Sciences (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60028787",
#                 "affiliation-id": "60028787",
#                 "affiliation-name": "Macalester College",
#                 "affiliation-city": "Minneapolis",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57198881202"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857198881202%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57198881202&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57198881202&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57198881202",
#             "dc:identifier": "AUTHOR_ID:57198881202",
#             "eid": "9-s2.0-57198881202",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher D.",
#                 "initials": "C.D."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C.",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "7",
#             "subject-area": [
#                 {
#                     "@abbrev": "NEUR",
#                     "@frequency": "7",
#                     "$": "Neuroscience (all)"
#                 },
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "6",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "2",
#                     "$": "Medicine (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60006385",
#                 "affiliation-id": "60006385",
#                 "affiliation-name": "Boston University School of Medicine",
#                 "affiliation-city": "Boston",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/56008583500"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856008583500%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56008583500&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56008583500&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/56008583500",
#             "dc:identifier": "AUTHOR_ID:56008583500",
#             "eid": "9-s2.0-56008583500",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher W.",
#                 "initials": "C.W."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C. W.",
#                     "initials": "C.W."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C. G.",
#                     "initials": "C.G."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "7",
#             "subject-area": [
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "7",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "PHAR",
#                     "@frequency": "4",
#                     "$": "Pharmacology, Toxicology and Pharmaceutics (all)"
#                 },
#                 {
#                     "@abbrev": "CHEM",
#                     "@frequency": "1",
#                     "$": "Chemistry (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/100320462",
#                 "affiliation-id": "100320462",
#                 "affiliation-name": "Icagen Inc.",
#                 "affiliation-city": "Durham",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/58345825500"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2858345825500%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=58345825500&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=58345825500&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/58345825500",
#             "dc:identifier": "AUTHOR_ID:58345825500",
#             "eid": "9-s2.0-58345825500",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher",
#                 "initials": "C."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "C.",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "5",
#             "subject-area": [
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "5",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "1",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60012508",
#                 "affiliation-id": "60012508",
# ...
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=24469511600&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/24469511600",
#             "dc:identifier": "AUTHOR_ID:24469511600",
#             "eid": "9-s2.0-24469511600",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher J.",
#                 "initials": "C.J."
#             },
#             "document-count": "5",
#             "subject-area": [
#                 {
#                     "@abbrev": "ENGI",
#                     "@frequency": "5",
#                     "$": "Engineering (all)"
#                 },
#                 {
#                     "@abbrev": "BUSI",
#                     "@frequency": "5",
#                     "$": "Business, Management and Accounting (all)"
#                 },
#                 {
#                     "@abbrev": "DECI",
#                     "@frequency": "1",
#                     "$": "Decision Sciences (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60020251",
#                 "affiliation-id": "60020251",
#                 "affiliation-name": "Air Force Institute of Technology",
#                 "affiliation-city": "Dayton",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/15838351300"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2815838351300%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=15838351300&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=15838351300&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/15838351300",
#             "dc:identifier": "AUTHOR_ID:15838351300",
#             "eid": "9-s2.0-15838351300",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher E.",
#                 "initials": "C.E."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "5",
#             "subject-area": [
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "5",
#                     "$": "Medicine (all)"
#                 },
#                 {
#                     "@abbrev": "HEAL",
#                     "@frequency": "2",
#                     "$": "Health Professions  (all)"
#                 },
#                 {
#                     "@abbrev": "SOCI",
#                     "@frequency": "2",
#                     "$": "Social Sciences (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60023691",
#                 "affiliation-id": "60023691",
#                 "affiliation-name": "University of California, San Francisco",
#                 "affiliation-city": "San Francisco",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57198881210"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857198881210%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57198881210&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57198881210&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57198881210",
#             "dc:identifier": "AUTHOR_ID:57198881210",
#             "eid": "9-s2.0-57198881210",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher W.",
#                 "initials": "C.W."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "4",
#             "subject-area": [
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "17",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "PHAR",
#                     "@frequency": "4",
#                     "$": "Pharmacology, Toxicology and Pharmaceutics (all)"
#                 },
#                 {
#                     "@abbrev": "CHEM",
#                     "@frequency": "3",
#                     "$": "Chemistry (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60006680",
#                 "affiliation-id": "60006680",
#                 "affiliation-name": "Bayer AG",
#                 "affiliation-city": "Leverkusen",
#                 "affiliation-country": "Germany"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/58350386400"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2858350386400%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=58350386400&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=58350386400&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/58350386400",
#             "dc:identifier": "AUTHOR_ID:58350386400",
#             "eid": "9-s2.0-58350386400",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Chris",
#                 "initials": "C."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "3",
#             "subject-area": [
#                 {
#                     "@abbrev": "ENGI",
#                     "@frequency": "2",
#                     "$": "Engineering (all)"
#                 },
#                 {
#                     "@abbrev": "PHYS",
#                     "@frequency": "2",
#                     "$": "Physics and Astronomy (all)"
#                 },
#                 {
#                     "@abbrev": "MULT",
#                     "@frequency": "1",
#                     "$": "Multidisciplinary"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60025590",
#                 "affiliation-id": "60025590",
#                 "affiliation-name": "SLAC National Accelerator Laboratory",
#                 "affiliation-city": "Menlo Park",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57221673643"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857221673643%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57221673643&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57221673643&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57221673643",
#             "dc:identifier": "AUTHOR_ID:57221673643",
#             "eid": "9-s2.0-57221673643",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher",
#                 "initials": "C."
#             },
#             "document-count": "3",
#             "subject-area": [
#                 {
#                     "@abbrev": "BIOC",
#                     "@frequency": "4",
#                     "$": "Biochemistry, Genetics and Molecular Biology (all)"
#                 },
#                 {
#                     "@abbrev": "MEDI",
#                     "@frequency": "3",
#                     "$": "Medicine (all)"
#                 }
#             ],
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60024724",
#                 "affiliation-id": "60024724",
#                 "affiliation-name": "University of Strathclyde",
#                 "affiliation-city": "Glasgow",
#                 "affiliation-country": "United Kingdom"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/57202115454"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2857202115454%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=57202115454&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=57202115454&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/57202115454",
#             "dc:identifier": "AUTHOR_ID:57202115454",
#             "eid": "9-s2.0-57202115454",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher R.",
#                 "initials": "C.R."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher R.",
#                     "initials": "C.R."
#                 },
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Christopher",
#                     "initials": "C."
#                 }
#             ],
#             "document-count": "3",
#             "subject-area": {
#                 "@abbrev": "MEDI",
#                 "@frequency": "1",
#                 "$": "Medicine (all)"
#             },
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60024324",
#                 "affiliation-id": "60024324",
#                 "affiliation-name": "University of Iowa",
#                 "affiliation-city": "Iowa City",
#                 "affiliation-country": "United States"
#             }
#         },
#         {
#             "@_fa": "true",
#             "link": [
#                 {
#                     "@_fa": "true",
#                     "@ref": "self",
#                     "@href": "https://api.elsevier.com/content/author/author_id/56232410600"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "search",
#                     "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856232410600%29"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-citedby",
#                     "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56232410600&origin=inward"
#                 },
#                 {
#                     "@_fa": "true",
#                     "@ref": "scopus-author",
#                     "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410600&origin=inward"
#                 }
#             ],
#             "prism:url": "https://api.elsevier.com/content/author/author_id/56232410600",
#             "dc:identifier": "AUTHOR_ID:56232410600",
#             "eid": "9-s2.0-56232410600",
#             "preferred-name": {
#                 "surname": "West",
#                 "given-name": "Christopher W.",
#                 "initials": "C.W."
#             },
#             "name-variant": [
#                 {
#                     "@_fa": "true",
#                     "surname": "West",
#                     "given-name": "Chris W.",
#                     "initials": "C.W."
#                 }
#             ],
#             "document-count": "3",
#             "subject-area": {
#                 "@abbrev": "BIOC",
#                 "@frequency": "3",
#                 "$": "Biochemistry, Genetics and Molecular Biology (all)"
#             },
#             "affiliation-current": {
#                 "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60032179",
#                 "affiliation-id": "60032179",
#                 "affiliation-name": "University of Wisconsin-Madison",
#                 "affiliation-city": "Madison",
#                 "affiliation-country": "United States"
#             }
#         }
#     ]
# }

# %%
data_str = json.dumps(data["search-results"]["entry"][1], indent=4)
print(data_str)
# Out:
# {
#     "@_fa": "true",
#     "link": [
#         {
#             "@_fa": "true",
#             "@ref": "self",
#             "@href": "https://api.elsevier.com/content/author/author_id/56232410100"
#         },
#         {
#             "@_fa": "true",
#             "@ref": "search",
#             "@href": "https://api.elsevier.com/content/search/author?query=au-id%2856232410100%29"
#         },
#         {
#             "@_fa": "true",
#             "@ref": "scopus-citedby",
#             "@href": "https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=56232410100&origin=inward"
#         },
#         {
#             "@_fa": "true",
#             "@ref": "scopus-author",
#             "@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410100&origin=inward"
#         }
#     ],
#     "prism:url": "https://api.elsevier.com/content/author/author_id/56232410100",
#     "dc:identifier": "AUTHOR_ID:56232410100",
#     "eid": "9-s2.0-56232410100",
#     "preferred-name": {
#         "surname": "West",
#         "given-name": "Christopher R.",
#         "initials": "C.R."
#     },
#     "name-variant": [
#         {
#             "@_fa": "true",
#             "surname": "West",
#             "given-name": "Christopher R.",
#             "initials": "C.R."
#         },
#         {
#             "@_fa": "true",
#             "surname": "West",
#             "given-name": "C.",
#             "initials": "C."
#         },
#         {
#             "@_fa": "true",
#             "surname": "West",
#             "given-name": "Chris",
#             "initials": "C."
#         }
#     ],
#     "document-count": "91",
#     "subject-area": [
#         {
#             "@abbrev": "MEDI",
#             "@frequency": "143",
#             "$": "Medicine (all)"
#         },
#         {
#             "@abbrev": "BIOC",
#             "@frequency": "27",
#             "$": "Biochemistry, Genetics and Molecular Biology (all)"
#         },
#         {
#             "@abbrev": "NEUR",
#             "@frequency": "25",
#             "$": "Neuroscience (all)"
#         }
#     ],
#     "affiliation-current": {
#         "affiliation-url": "https://api.elsevier.com/content/affiliation/affiliation_id/60023077",
#         "affiliation-id": "60023077",
#         "affiliation-name": "University of British Columbia, Faculty of Medicine",
#         "affiliation-city": "Vancouver",
#         "affiliation-country": "Canada"
#     }
# }

# %%
auth_id = data["search-results"]["entry"][1]["dc:identifier"].split(":",1)[1]
print(auth_id)
# Out:
# 56232410100

# %%
# Author Retrieval
# documentation: https://dev.elsevier.com/documentation/AuthorRetrievalAPI.wadl

author_id = "56232410100"

url = "https://api.elsevier.com/content/author"
url = f"https://api.elsevier.com/content/author/author_id/{author_id}"

params = {
    "views": "documents",
}

ar_response = requests.get(url=url,
                        params=params, 
                        headers=headers)
print(ar_response)
ar_data = json.loads(ar_response.text)
print(ar_data)
# Out:
# <Response [200]>
# {'author-retrieval-response': [{'@status': 'found', '@_fa': 'true', 'coredata': {'prism:url': 'http://api.elsevier.com/content/author/author_id/56232410100', 'dc:identifier': 'AUTHOR_ID:56232410100', 'eid': '9-s2.0-56232410100', 'document-count': '91', 'cited-by-count': '1173', 'citation-count': '1919', 'link': [{'@href': 'https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410100&origin=inward', '@rel': 'scopus-author', '@_fa': 'true'}, {'@href': 'http://api.elsevier.com/content/author/author_id/56232410100', '@rel': 'self', '@_fa': 'true'}, {'@href': 'http://api.elsevier.com/content/search/scopus?query=au-id%2856232410100%29', '@rel': 'search', '@_fa': 'true'}]}, 'affiliation-current': {'@id': '125535019', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/125535019'}, 'affiliation-history': {'affiliation': [{'@_fa': 'true', '@id': '60010365', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60010365'}, {'@_fa': 'true', '@id': '60023077', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60023077'}, {'@_fa': 'true', '@id': '60012967', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60012967'}, {'@_fa': 'true', '@id': '60193424', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60193424'}, {'@_fa': 'true', '@id': '60120209', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60120209'}, {'@_fa': 'true', '@id': '113629203', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/113629203'}, {'@_fa': 'true', '@id': '121642867', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/121642867'}, {'@_fa': 'true', '@id': '60004982', '@href': 'http://api.elsevier.com/content/affiliation/affiliation_id/60004982'}]}, 'subject-areas': {'subject-area': [{'@_fa': 'true', '@abbrev': 'PHYS', '@code': '3100', '$': 'Physics and Astronomy (all)'}, {'@_fa': 'true', '@abbrev': 'IMMU', '@code': '2400', '$': 'Immunology and Microbiology (all)'}, {'@_fa': 'true', '@abbrev': 'NEUR', '@code': '2808', '$': 'Neurology'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2728', '$': 'Neurology (clinical)'}, {'@_fa': 'true', '@abbrev': 'HEAL', '@code': '3612', '$': 'Physical Therapy, Sports Therapy and Rehabilitation'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2739', '$': 'Public Health, Environmental and Occupational Health'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2737', '$': 'Physiology (medical)'}, {'@_fa': 'true', '@abbrev': 'AGRI', '@code': '1100', '$': 'Agricultural and Biological Sciences (all)'}, {'@_fa': 'true', '@abbrev': 'NEUR', '@code': '2806', '$': 'Developmental Neuroscience'}, {'@_fa': 'true', '@abbrev': 'BIOC', '@code': '1314', '$': 'Physiology'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2742', '$': 'Rehabilitation'}, {'@_fa': 'true', '@abbrev': 'NEUR', '@code': '2801', '$': 'Neuroscience (miscellaneous)'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2724', '$': 'Internal Medicine'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2732', '$': 'Orthopedics and Sports Medicine'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2740', '$': 'Pulmonary and Respiratory Medicine'}, {'@_fa': 'true', '@abbrev': 'CHEM', '@code': '1600', '$': 'Chemistry (all)'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2700', '$': 'Medicine (all)'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2705', '$': 'Cardiology and Cardiovascular Medicine'}, {'@_fa': 'true', '@abbrev': 'NEUR', '@code': '2804', '$': 'Cellular and Molecular Neuroscience'}, {'@_fa': 'true', '@abbrev': 'NEUR', '@code': '2805', '$': 'Cognitive Neuroscience'}, {'@_fa': 'true', '@abbrev': 'NURS', '@code': '2916', '$': 'Nutrition and Dietetics'}, {'@_fa': 'true', '@abbrev': 'NEUR', '@code': '2800', '$': 'Neuroscience (all)'}, {'@_fa': 'true', '@abbrev': 'BIOC', '@code': '1300', '$': 'Biochemistry, Genetics and Molecular Biology (all)'}, {'@_fa': 'true', '@abbrev': 'MEDI', '@code': '2701', '$': 'Medicine (miscellaneous) ...

# %%
# Scopus Search API
# documentation: https://dev.elsevier.com/documentation/ScopusSearchAPI.wadl

author_id = "56232410100"

url = "https://api.elsevier.com/content/author"
url = f"https://api.elsevier.com/content/author/author_id/{author_id}"

headers = {
    "Accept": "application/json",
    "X-ELS-APIKey": api_key,
}
    
params = {
    "query" : f"au-id({author_id})",
}

ss_response = requests.get(url=url,
                        params=params, 
                        headers=headers)
# Out:
# <Response [200]>

# %%
print(ss_response.text)
# Out:
# {"author-retrieval-response": [{"@status": "found", "@_fa": "true", "coredata":{"prism:url":"http://api.elsevier.com/content/author/author_id/56232410100","dc:identifier":"AUTHOR_ID:56232410100","eid":"9-s2.0-56232410100","document-count":"91","cited-by-count":"1173","citation-count":"1919","link": [{"@href": "https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=56232410100&origin=inward", "@rel": "scopus-author", "@_fa": "true"},{"@href": "http://api.elsevier.com/content/author/author_id/56232410100", "@rel": "self", "@_fa": "true"},{"@href": "http://api.elsevier.com/content/search/scopus?query=au-id%2856232410100%29", "@rel": "search", "@_fa": "true"}]},"affiliation-current":{"@id": "125535019", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/125535019"},"affiliation-history":{"affiliation": [{"@_fa": "true", "@id": "60010365", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/60010365"},{"@_fa": "true", "@id": "60023077", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/60023077"},{"@_fa": "true", "@id": "60012967", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/60012967"},{"@_fa": "true", "@id": "60193424", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/60193424"},{"@_fa": "true", "@id": "60120209", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/60120209"},{"@_fa": "true", "@id": "113629203", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/113629203"},{"@_fa": "true", "@id": "121642867", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/121642867"},{"@_fa": "true", "@id": "60004982", "@href": "http://api.elsevier.com/content/affiliation/affiliation_id/60004982"}]},"subject-areas":{"subject-area": [{"@_fa": "true", "@abbrev": "PHYS", "@code": "3100", "$" :"Physics and Astronomy (all)"},{"@_fa": "true", "@abbrev": "IMMU", "@code": "2400", "$" :"Immunology and Microbiology (all)"},{"@_fa": "true", "@abbrev": "NEUR", "@code": "2808", "$" :"Neurology"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2728", "$" :"Neurology (clinical)"},{"@_fa": "true", "@abbrev": "HEAL", "@code": "3612", "$" :"Physical Therapy, Sports Therapy and Rehabilitation"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2739", "$" :"Public Health, Environmental and Occupational Health"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2737", "$" :"Physiology (medical)"},{"@_fa": "true", "@abbrev": "AGRI", "@code": "1100", "$" :"Agricultural and Biological Sciences (all)"},{"@_fa": "true", "@abbrev": "NEUR", "@code": "2806", "$" :"Developmental Neuroscience"},{"@_fa": "true", "@abbrev": "BIOC", "@code": "1314", "$" :"Physiology"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2742", "$" :"Rehabilitation"},{"@_fa": "true", "@abbrev": "NEUR", "@code": "2801", "$" :"Neuroscience (miscellaneous)"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2724", "$" :"Internal Medicine"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2732", "$" :"Orthopedics and Sports Medicine"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2740", "$" :"Pulmonary and Respiratory Medicine"},{"@_fa": "true", "@abbrev": "CHEM", "@code": "1600", "$" :"Chemistry (all)"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2700", "$" :"Medicine (all)"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2705", "$" :"Cardiology and Cardiovascular Medicine"},{"@_fa": "true", "@abbrev": "NEUR", "@code": "2804", "$" :"Cellular and Molecular Neuroscience"},{"@_fa": "true", "@abbrev": "NEUR", "@code": "2805", "$" :"Cognitive Neuroscience"},{"@_fa": "true", "@abbrev": "NURS", "@code": "2916", "$" :"Nutrition and Dietetics"},{"@_fa": "true", "@abbrev": "NEUR", "@code": "2800", "$" :"Neuroscience (all)"},{"@_fa": "true", "@abbrev": "BIOC", "@code": "1300", "$" :"Biochemistry, Genetics and Molecular Biology (all)"},{"@_fa": "true", "@abbrev": "MEDI", "@code": "2701", "$" :"Medicine (miscellaneous)"},{"@_fa": "true", "@abbrev": "MULT", "@code": "10 ...

# %%
# Citations Overview API
# documentation: 
url = "https://api.elsevier.com/content/abstract/citations"

params = {
    "scopus_id" : scopus_id,
}

co_response = requests.get(url=url,
                        params=params, 
                        headers=headers)
co_data = json.loads(co_response.text)
print(co_data)
# Out:
# {'service-error': {'status': {'statusCode': 'INVALID_INPUT', 'statusText': 'Identifier must be specified'}}}

# %%
# Citations Overview API
author_id = "56232410100"
params = {
    "view": f"identifier
}
co_response = requests.get(url=url,
                        params=params, 
                        headers=headers)
co_data = json.loads(co_response.text)
print(co_data)

# %% [markdown]
# ## using pybliometrics

# %%
from pybliometrics.scopus import CitationOverview, AuthorSearch, AuthorRetrieval


# AuthorSearch documentation:

# %%
s = AuthorSearch(f"authlast({lastname}) and authfirst({firstname})")

# %%
print(s)
# Out:
# Search 'authlast(West) and authfirst(Christopher)' yielded 44 authors as of 2023-09-11:
#     West, Christopher M.; AUTHOR_ID:7402187736 (122 document(s))
#     West, Christopher R.; AUTHOR_ID:56232410100 (91 document(s))
#     West, Christopher Robert; AUTHOR_ID:57209151783 (72 document(s))
#     Hamilton-West, Christopher; AUTHOR_ID:25223111300 (44 document(s))
#     West, Christopher C.; AUTHOR_ID:55777163700 (38 document(s))
#     West, Christopher E.; AUTHOR_ID:57210969623 (35 document(s))
#     West, Chris D.; AUTHOR_ID:56763374400 (27 document(s))
#     West, Christopher K.; AUTHOR_ID:56719058800 (19 document(s))
#     West, Christopher W.; AUTHOR_ID:55843206800 (19 document(s))
#     West, Christopher L.; AUTHOR_ID:7402188605 (14 document(s))
#     West, Christopher J.; AUTHOR_ID:8707935900 (13 document(s))
#     West, Alexander Christopher; AUTHOR_ID:55711289900 (12 document(s))
#     West, Christopher P.C.P.; AUTHOR_ID:57218339832 (10 document(s))
#     West, Christopher J.; AUTHOR_ID:57213445762 (9 document(s))
#     West, Christopher D.; AUTHOR_ID:57198881202 (7 document(s))
#     West, Christopher W.; AUTHOR_ID:56008583500 (7 document(s))
#     West, Christopher; AUTHOR_ID:58345825500 (5 document(s))
#     West, Christopher J.; AUTHOR_ID:57195803299 (5 document(s))
#     West, Christopher J.; AUTHOR_ID:24469511600 (5 document(s))
#     West, Christopher E.; AUTHOR_ID:15838351300 (5 document(s))
#     West, Christopher W.; AUTHOR_ID:57198881210 (4 document(s))
#     West, Chris; AUTHOR_ID:58350386400 (3 document(s))
#     West, Christopher; AUTHOR_ID:57221673643 (3 document(s))
#     West, Christopher R.; AUTHOR_ID:57202115454 (3 document(s))
#     West, Christopher W.; AUTHOR_ID:56232410600 (3 document(s))
#     West, Andrew Christopher; AUTHOR_ID:36443075600 (3 document(s))
#     West, Christopher; AUTHOR_ID:57209151785 (2 document(s))
#     West, Christopher L.; AUTHOR_ID:36496223100 (2 document(s))
#     West, Christopher C.; AUTHOR_ID:9844874600 (1 document(s))
#     West, Christopher R.; AUTHOR_ID:8683899700 (1 document(s))
#     West, Christopher L.; AUTHOR_ID:7402187751 (1 document(s))
#     West, Christopher; AUTHOR_ID:57395098600 (1 document(s))
#     West, Christopher C.; AUTHOR_ID:57225694259 (1 document(s))
#     West, Christopher R.; AUTHOR_ID:57225191229 (1 document(s))
#     West, Christopher; AUTHOR_ID:57222084250 (1 document(s))
#     West, Christopher; AUTHOR_ID:57218575934 (1 document(s))
#     West, Christopher; AUTHOR_ID:57208994435 (1 document(s))
#     West, Christopher; AUTHOR_ID:57203617018 (1 document(s))
#     West, Christopher; AUTHOR_ID:57202083923 (1 document(s))
#     West, Christopher; AUTHOR_ID:57198881246 (1 document(s))
#     West, Christopher H.; AUTHOR_ID:57192232306 (1 document(s))
#     Hamilton-West M, Christopher; AUTHOR_ID:51461304000 (1 document(s))
#     West, Christopher; AUTHOR_ID:36780984200 (1 document(s))
#     West, Bryan Christopher; AUTHOR_ID:36680981700 (1 document(s))

# %%
s.authors[0]
# Out:
# Author(eid='9-s2.0-7402187736', orcid=None, surname='West', initials='C.M.', givenname='Christopher M.', affiliation='University of Georgia', documents=122, affiliation_id='60029747', city='Athens', country='United States', areas='BIOC (261); MEDI (56); IMMU (25)')

# %%
for i in range(s.get_results_size()):
    print(s.authors[i])
    try:
        print(s.authors[i].affiliation + "\n") # access specific attribute of author
    except TypeError:
        print("no affiliation found for author\n")
# Out:
# Author(eid='9-s2.0-7402187736', orcid=None, surname='West', initials='C.M.', givenname='Christopher M.', affiliation='University of Georgia', documents=122, affiliation_id='60029747', city='Athens', country='United States', areas='BIOC (261); MEDI (56); IMMU (25)')
# University of Georgia
#
# Author(eid='9-s2.0-56232410100', orcid=None, surname='West', initials='C.R.', givenname='Christopher R.', affiliation='University of British Columbia, Faculty of Medicine', documents=91, affiliation_id='60023077', city='Vancouver', country='Canada', areas='MEDI (143); BIOC (27); NEUR (25)')
# University of British Columbia, Faculty of Medicine
#
# Author(eid='9-s2.0-57209151783', orcid=None, surname='West', initials='C.R.', givenname='Christopher Robert', affiliation='University of Liverpool', documents=72, affiliation_id='60020661', city='Liverpool', country='United Kingdom', areas='MEDI (113); BIOC (24); PHAR (8)')
# University of Liverpool
#
# Author(eid='9-s2.0-25223111300', orcid='0000-0002-5609-2237', surname='Hamilton-West', initials='C.', givenname='Christopher', affiliation='Universidad de Chile', documents=44, affiliation_id='60012464', city='Santiago', country='Chile', areas='MEDI (50); AGRI (27); VETE (26)')
# Universidad de Chile
#
# Author(eid='9-s2.0-55777163700', orcid=None, surname='West', initials='C.C.', givenname='Christopher C.', affiliation='University of Edinburgh, MRC Centre for Regenerative Medicine', documents=38, affiliation_id='60014873', city='Edinburgh', country='United Kingdom', areas='MEDI (70); BIOC (33); MATE (5)')
# University of Edinburgh, MRC Centre for Regenerative Medicine
#
# Author(eid='9-s2.0-57210969623', orcid=None, surname='West', initials='C.E.', givenname='Christopher E.', affiliation='University of Leeds', documents=35, affiliation_id='60012070', city='Leeds', country='United Kingdom', areas='AGRI (34); BIOC (34); MEDI (9)')
# University of Leeds
#
# Author(eid='9-s2.0-56763374400', orcid='0000-0002-5091-6514', surname='West', initials='C.D.', givenname='Chris D.', affiliation='University of York', documents=27, affiliation_id='60016418', city='York', country='United Kingdom', areas='ENVI (35); SOCI (10); ENER (8)')
# University of York
#
# Author(eid='9-s2.0-56719058800', orcid='0000-0003-1193-0986', surname='West', initials='C.K.', givenname='Christopher K.', affiliation='University of Alberta', documents=19, affiliation_id='60030835', city='Edmonton', country='Canada', areas='EART (31); AGRI (8); MEDI (1)')
# University of Alberta
#
# Author(eid='9-s2.0-55843206800', orcid=None, surname='West', initials='C.W.', givenname='Christopher W.', affiliation='Kyoto University', documents=19, affiliation_id='60011001', city='Kyoto', country='Japan', areas='CHEM (16); PHYS (11); MATE (6)')
# Kyoto University
#
# Author(eid='9-s2.0-7402188605', orcid=None, surname='West', initials='C.L.', givenname='Christopher L.', affiliation='Defence Science and Technology Laboratory', documents=14, affiliation_id='60026242', city='Salisbury', country='United Kingdom', areas='ENGI (12); PHYS (3)')
# Defence Science and Technology Laboratory
#
# Author(eid='9-s2.0-8707935900', orcid=None, surname='West', initials='C.J.', givenname='Christopher J.', affiliation='AgResearch Grasslands', documents=13, affiliation_id='60032306', city='Palmerston North', country='New Zealand', areas='AGRI (14); VETE (6); IMMU (3)')
# AgResearch Grasslands
#
# Author(eid='9-s2.0-55711289900', orcid=None, surname='West', initials='A.C.', givenname='Alexander Christopher', affiliation='UiT Norges Arktiske Universitet', documents=12, affiliation_id='60021255', city='Tromso', country='Norway', areas='BIOC (14); MEDI (13); AGRI (9)')
# UiT Norges Arktiske Universitet
#
# Author(eid='9-s2.0-57218339832', orcid=None, surname='West', initials='C.P.C.P.', givenname='Christopher P.C.P.', affiliation='College of Science', documents=10, affiliation_id='60028629', city='West Lafayette', country='United States', areas='ENVI (10); CHEM (6); MEDI (6)')
# College of Science
#
# Author(eid='9-s2.0-57213445762', orcid=None, surname='West', initials='C.J.', givenname='Christopher J.', affiliation='Macalester College', documents=9, affiliation_id='60028787', city='Minneapolis', country='United States', areas='PHYS (11); EART (7)')
# Macalester College
#
# Author(eid='9-s2.0-57198881202', orcid=None, surname='West', initials='C.D.', givenname='Christopher D.', affiliation='Boston University School of Medicine', documents=7, affiliation_id='60006385', city='Boston', country='United States', areas='NEUR (7); BIOC (6); MEDI (2)')
# Boston University School of Medicine
#
# Author(eid='9-s2.0-56008583500', orcid=None, surname='West', initials='C.W.', givenname='Christopher W.', affiliation='Icagen Inc.', documents=7, affiliation_id='100320462', city='Durham', country='United States', areas='BIOC (7); PHAR (4); CHEM (1)')
# Icagen Inc.
#
# Author(eid='9-s2.0-58345825500', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='Leeds Teaching Hospitals NHS Trust', documents=5, affiliation_id='60012508', city='Leeds', country='United Kingdom', areas='MEDI (5); BIOC (1)')
# Leeds Teaching Hospitals NHS Trust
#
# Author(eid='9-s2.0-57195803299', orcid=None, surname='West', initials='C.J.', givenname='Christopher J.', affiliation='YUROK TRIBE', documents=5, affiliation_id='114597431', city='KLAMATH', country='United States', areas='MEDI (3); MULT (2); ENVI (2)')
# YUROK TRIBE
#
# Author(eid='9-s2.0-24469511600', orcid=None, surname='West', initials='C.J.', givenname='Christopher J.', affiliation='Air Force Institute of Technology', documents=5, affiliation_id='60020251', city='Dayton', country='United States', areas='ENGI (5); BUSI (5); DECI (1)')
# Air Force Institute of Technology
#
# Author(eid='9-s2.0-15838351300', orcid=None, surname='West', initials='C.E.', givenname='Christopher E.', affiliation='University of California, San Francisco', documents=5, affiliation_id='60023691', city='San Francisco', country='United States', areas='MEDI (5); HEAL (2); SOCI (2)')
# University of California, San Francisco
#
# Author(eid='9-s2.0-57198881210', orcid=None, surname='West', initials='C.W.', givenname='Christopher W.', affiliation='Bayer AG', documents=4, affiliation_id='60006680', city='Leverkusen', country='Germany', areas='BIOC (17); PHAR (4); CHEM (3)')
# Bayer AG
#
# Author(eid='9-s2.0-58350386400', orcid=None, surname='West', initials='C.', givenname='Chris', affiliation='SLAC National Accelerator Laboratory', documents=3, affiliation_id='60025590', city='Menlo Park', country='United States', areas='ENGI (2); PHYS (2); MULT (1)')
# SLAC National Accelerator Laboratory
#
# Author(eid='9-s2.0-57221673643', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='University of Strathclyde', documents=3, affiliation_id='60024724', city='Glasgow', country='United Kingdom', areas='BIOC (4); MEDI (3)')
# University of Strathclyde
#
# Author(eid='9-s2.0-57202115454', orcid=None, surname='West', initials='C.R.', givenname='Christopher R.', affiliation='University of Iowa', documents=3, affiliation_id='60024324', city='Iowa City', country='United States', areas='MEDI (1)')
# University of Iowa
#
# Author(eid='9-s2.0-56232410600', orcid=None, surname='West', initials='C.W.', givenname='Christopher W.', affiliation='University of Wisconsin-Madison', documents=3, affiliation_id='60032179', city='Madison', country='United States', areas='BIOC (3)')
# University of Wisconsin-Madison
#
# Author(eid='9-s2.0-36443075600', orcid=None, surname='West', initials='A.C.', givenname='Andrew Christopher', affiliation='University of Kansas', documents=3, affiliation_id='60015457', city='Lawrence', country='United States', areas='ARTS (3); SOCI (2)')
# University of Kansas
#
# Author(eid='9-s2.0-57209151785', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='Cambridge Market Intelligence', documents=2, affiliation_id='101020338', city='London', country='United Kingdom', areas='BUSI (3); ECON (1)')
# Cambridge Market Intelligence
#
# Author(eid='9-s2.0-36496223100', orcid=None, surname='West', initials='C.L.', givenname='Christopher L.', affiliation='212th Combat Stress Control', documents=2, affiliation_id='109603752', city=None, country='United States', areas='MEDI (2); PSYC (1)')
# 212th Combat Stress Control
#
# Author(eid='9-s2.0-9844874600', orcid=None, surname='West', initials='C.C.', givenname='Christopher C.', affiliation='International Business Machines', documents=1, affiliation_id='60021293', city='Armonk', country='United States', areas='COMP (1)')
# International Business Machines
#
# Author(eid='9-s2.0-8683899700', orcid=None, surname='West', initials='C.R.', givenname='Christopher R.', affiliation='Brigham Young University', documents=1, affiliation_id='60006832', city='Provo', country='United States', areas='ENGI (1)')
# Brigham Young University
#
# Author(eid='9-s2.0-7402187751', orcid=None, surname='West', initials='C.L.', givenname='Christopher L.', affiliation=None, documents=1, affiliation_id=None, city=None, country=None, areas='ENGI (2); CENG (1)')
# no affiliation found for author
#
# Author(eid='9-s2.0-57395098600', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation=None, documents=1, affiliation_id=None, city=None, country=None, areas='ARTS (1)')
# no affiliation found for author
#
# Author(eid='9-s2.0-57225694259', orcid=None, surname='West', initials='C.C.', givenname='Christopher C.', affiliation='University of Edinburgh, MRC Centre for Regenerative Medicine', documents=1, affiliation_id='60014873', city='Edinburgh', country='United Kingdom', areas='MEDI (3)')
# University of Edinburgh, MRC Centre for Regenerative Medicine
#
# Author(eid='9-s2.0-57225191229', orcid=None, surname='West', initials='C.R.', givenname='Christopher R.', affiliation='Washington University in St. Louis', documents=1, affiliation_id='60010261', city='St. Louis', country='United States', areas='MEDI (1)')
# Washington University in St. Louis
#
# Author(eid='9-s2.0-57222084250', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='The University of British Columbia', documents=1, affiliation_id='60010365', city='Vancouver', country='Canada', areas='COMP (2)')
# The University of British Columbia
#
# Author(eid='9-s2.0-57218575934', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='University of Alberta', documents=1, affiliation_id='60030835', city='Edmonton', country='Canada', areas='MATH (1); COMP (1)')
# University of Alberta
#
# Author(eid='9-s2.0-57208994435', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='Swansea University', documents=1, affiliation_id='60004572', city='Swansea', country='United Kingdom', areas='SOCI (1)')
# Swansea University
#
# Author(eid='9-s2.0-57203617018', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='University of Birmingham', documents=1, affiliation_id='60019702', city='Birmingham', country='United Kingdom', areas='ENVI (1); CENG (1)')
# University of Birmingham
#
# Author(eid='9-s2.0-57202083923', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='Smith College', documents=1, affiliation_id='60001525', city='Northampton', country='United States', areas='PHYS (1)')
# Smith College
#
# Author(eid='9-s2.0-57198881246', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation=None, documents=1, affiliation_id=None, city=None, country=None, areas='MATE (2); PHYS (1); MEDI (1)')
# no affiliation found for author
#
# Author(eid='9-s2.0-57192232306', orcid=None, surname='West', initials='C.H.', givenname='Christopher H.', affiliation='University of Maine', documents=1, affiliation_id='60008279', city='Orono', country='United States', areas='ENGI (3); MATE (1)')
# University of Maine
#
# Author(eid='9-s2.0-51461304000', orcid=None, surname='Hamilton-West M', initials='C.', givenname='Christopher', affiliation='Facultad de Medicina de la Universidad de Chile', documents=1, affiliation_id='60002946', city='Santiago', country='Chile', areas='MEDI (1)')
# Facultad de Medicina de la Universidad de Chile
#
# Author(eid='9-s2.0-36780984200', orcid=None, surname='West', initials='C.', givenname='Christopher', affiliation='Royal Dutch Shell', documents=1, affiliation_id='60030496', city='Den Haag', country='Netherlands', areas='ENGI (1); CENG (1); ENER (1)')
# Royal Dutch Shell
#
# Author(eid='9-s2.0-36680981700', orcid=None, surname='West', initials='B.C.', givenname='Bryan Christopher', affiliation='Foot Healthcare Associates', documents=1, affiliation_id='109724393', city='Southfield', country='United States', areas='MEDI (1); HEAL (1)')
# Foot Healthcare Associates

# %%
# AuthorRetrieval documentation: https://pybliometrics.readthedocs.io/en/latest/classes/AuthorRetrieval.html

ar = AuthorRetrieval(56232410100)
ar_documents = AuthorRetrieval(56232410100).get_documents()

# %%
print(ar)
print(ar_documents)
# Out:
# West C. from Department of Cellular and Physiological Sciences in Canada,
# published 91 document(s) since 2010
# which were cited by 1,173 author(s) in 1,919 document(s) as of 2023-09-11
# [Document(eid='2-s2.0-85145701306', doi='10.1113/JP283979', pii=None, pubmed_id='36542455', title='Acute hypoxia elicits lasting reductions in the sympathetic action potential transduction of arterial blood pressure in males', subtype='ar', subtypeDescription='Article', creator='Shafer B.M.', afid='60023077;60015881;60012967;60010365', affilname='University of British Columbia, Faculty of Medicine;University of Guelph;University of British Columbia Okanagan;The University of British Columbia', affiliation_city='Vancouver;Guelph;Kelowna;Vancouver', affiliation_country='Canada;Canada;Canada;Canada', author_count='10', author_names='Shafer, Brooke M.;Nardone, Massimo;Incognito, Anthony V.;Vermeulen, Tyler D.;Teixeira, André L.;Millar, Philip J.;Sheel, A. William;West, Chris;Ayas, Najib;Foster, Glen E.', author_ids='57214328545;57191889837;56974263200;57198864082;55553445800;14825521500;6604075865;56232410100;7003854089;7403211837', author_afids='60012967;60015881;60015881;60012967;60015881;60015881;60010365;60023077-60010365-60012967;60023077;60012967', coverDate='2023-02-01', coverDisplayDate='1 February 2023', publicationName='Journal of Physiology', issn='00223751', source_id='23478', eIssn='14697793', aggregationType='Journal', volume='601', issueIdentifier='3', article_number=None, pageRange='669-687', description='Abstract: Post-hypoxia sympathoexcitation does not elicit corresponding changes in vascular tone, suggesting diminished sympathetic signalling. Blunted sympathetic transduction following acute hypoxia, however, has not been confirmed and the effects of hypoxia on the sympathetic transduction of mean arterial pressure (MAP) as a function of action potential (AP) activity is unknown. We hypothesized that MAP changes would be blunted during acute hypoxia but restored in recovery and asynchronous APs would elicit smaller MAP changes than synchronous APs. Seven healthy males (age: 24 (3) years; BMI: 25 (3) kg/m2) underwent 20\xa0min isocapnic hypoxia (PETO2: 47 (2) mmHg) and 30\xa0min recovery. Multi-unit microneurography (muscle sympathetic nerve activity; MSNA) and continuous wavelet transform with matched mother wavelet was used to detect sympathetic APs during baseline, hypoxia, early (first 7\xa0min) and late (last 7\xa0min) recovery. AP groups were classified as synchronous APs, asynchronous APs (occurring outside an MSNA burst) and no AP activity. Sympathetic transduction of MAP was quantified using signal-averaging, with ΔMAP tracked following AP group cardiac cycles. Following synchronous APs, ΔMAP was reduced in hypoxia (+1.8 (0.9) mmHg) and early recovery (+1.5 (0.7) mmHg) compared with baseline (+3.1 (2.2) mmHg). AP group-by-condition interactions show that at rest asynchronous APs attenuate MAP reductions compared with no AP activity (−0.4 (1.1) vs. −2.2 (1.2) mmHg, respectively), with no difference between AP groups in hypoxia, early or late recovery. Sympathetic transduction of MAP is blunted in hypoxia and early recovery. At rest, asynchronous sympathetic APs contribute to neural regulation of MAP by attenuating nadir pressure responses. (Figure presented.). Key points: Acute isocapnic hypoxia elicits lasting sympathoexcitation that does not correspond to parallel changes in vascular tone, suggesting blunted sympathetic transduction. Signal-averaging techniques track the magnitude and temporal cardiovascular responses following integrated muscle sympathetic nerve activity (MSNA) burst and non-burst cardiac cycles. However, this does not fully characterize the effects of sympathetic action potential (AP) activity on blood pressure control. We show that hypoxia blunts the sympathetic transduction of mean arterial pressure (MAP) following synchronous APs that form integrated MSNA bursts and that sympathetic transduction of MAP remains attenuated into early recovery. At rest, asynchronous APs attenuate the reduction in MAP compared with cardiac cycles following no AP activity, thus asynchronous sympathetic  ...

# %%
# look at all the documents after 2013 publish date
adjusted_docs = [document.eid.split("-",2)[2] for document in ar_documents 
                 if int(document.coverDate.split("-")[0]) >= 2021]
print(len(adjusted_docs)) #CitationOverview can only parse 25 citations at a time
# Out:
# 20

# %%
# CitationOverview documentation: https://pybliometrics.readthedocs.io/en/stable/classes/CitationOverview.html

co = CitationOverview(adjusted_docs, start=2021)

# %%
print(co.cc)
# Out:
# [[(2021, 0), (2022, 0), (2023, 0)], [(2021, 0), (2022, 0), (2023, 0)], [(2021, 0), (2022, 0), (2023, 0)], [(2021, 0), (2022, 4), (2023, 1)], [(2021, 0), (2022, 1), (2023, 0)], [(2021, 0), (2022, 0), (2023, 2)], [(2021, 0), (2022, 1), (2023, 1)], [(2021, 0), (2022, 2), (2023, 1)], [(2021, 1), (2022, 3), (2023, 1)], [(2021, 0), (2022, 2), (2023, 0)], [(2021, 0), (2022, 4), (2023, 3)], [(2021, 0), (2022, 1), (2023, 0)], [(2021, 0), (2022, 1), (2023, 1)], [(2021, 2), (2022, 3), (2023, 0)], [(2021, 0), (2022, 1), (2023, 1)], [(2021, 1), (2022, 0), (2023, 0)], [(2021, 1), (2022, 0), (2023, 0)], [(2021, 0), (2022, 0), (2023, 0)], [(2021, 2), (2022, 3), (2023, 2)], [(2021, 1), (2022, 3), (2023, 3)]]
